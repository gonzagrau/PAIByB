# %% [markdown]
# # Estimación estadística del ruido mediante análisis de ROI homogéneas para imágenes de PAIBYB-2

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from stat_noise_estimation import load_stat_data, stat_noise_reconstruction, hist_noise_reconstruction

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Cargamos los datos obtenidos por los segmentos

# %%
datadir = 'infosaves'
data_dict, hist_dict = load_stat_data(datadir)

# %% [markdown]
# ## Reconstruimos el ruido con media y varianza

# %%
noise_dir = 'PAIByB-2'
output_dir = 'noise_estimation/stat_estimation'

stat_noise_reconstruction(data_dict, noise_dir, output_dir)

# %% [markdown]
# ## Reconstruimos el ruido analizando el histograma

# %%
output_dir = 'noise_estimation/hist_estimation'

hist_noise_reconstruction(hist_dict, noise_dir, output_dir)
# Out:
# /home/gonzagrau/miniconda3/envs/turcovenv/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:2027: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/gonzagrau/miniconda3/envs/turcovenv/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:2027: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# DMA=0.000
# DMA=2.029
# DMA=0.551
# DMA=2.748
# DMA=7.386
